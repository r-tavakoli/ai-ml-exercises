# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
v_2d = np.array([[3, -2]]) # 2 dimensional vector
v_3d = np.array([[4, -3, 2]]) # 3 dimensional vector

# %%
v_2dt = v_2d.T
v_2 = np.hstack((np.zeros(v_2dt.shape), v_2dt))
v_2

# %%
plt.plot(v_2[0], v_2[1])
plt.axis('equal')
plt.plot([-4, 4], [0, 0], 'k--')
plt.plot([0, 0], [-4, 4], 'k--')
plt.grid()
plt.xticks(np.arange(-4, 5))
plt.yticks(np.arange(-4, 5))
plt.axis((-4, 4, -4, 4))
plt.show()
