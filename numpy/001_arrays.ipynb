# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# array
arr_1d = np.array([1, 2, 3, 4, 5])
arr_2d = np.array([[1, 2], [3, 4]])

# special arrays
zeros = np.zeros((3, 4))
ones = np.ones((2, 3))
identity = np.eye(5)
random = np.random.randn(100, 100)

# plot
plt.figure(figsize=(12, 3))
plt.subplot(131); plt.imshow(zeros, cmap='gray'); plt.title('Zeros')
plt.subplot(132); plt.imshow(identity, cmap='gray'); plt.title('Identity')
plt.subplot(133); plt.imshow(random, cmap='gray'); plt.title('Random')
plt.show()
